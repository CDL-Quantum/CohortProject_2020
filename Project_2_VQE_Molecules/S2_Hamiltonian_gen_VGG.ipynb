# %% [markdown]
# # Generating Qubit Hamiltonians

# %%
import tequila as tq
from utility import *
import time

# %% [markdown]
# Specify the Qubit Hamiltonian of a molecule by its name, internuclear distances, basis set, and fermion-to-qubit transformation.
#
# Here, we go beyond showing the resulting Hamiltonian for $H_2$ in STO-3G with $1\overset{\circ}{A}$ between the $H$ atoms.

# %% [markdown]
# Alternatively, the qubit-tapering technique can find a smaller effective Hamitlonian by subsitituting operators with $\pm 1$. This technique is detailed in Bravyi's work ([Bravyi et al., "Tapering off qubits to simulate fermionic Hamiltonians", arXiv:1701.08213](https://arxiv.org/abs/1701.08213)).

# %%
molecules=['h2','h4','lih','h2o','n2','nh3']
methods=['hf','cisd','ccsd','fci']
basies=['sto-3g','6-31g']
qubit_transfms=['jw','bk'] 

qubit_transf = 'jw' # Jordan-Wigner transformations

# %% [markdown]
# We can verify that this new Hamiltonian indeed includes the ground state onl;y for H2 for now.

# %%
R=1 #bond_length

for mol in molecules:

    for basis in basies:

        for qubit_transf in qubit_transfms:
                    
            start=time.time()
            
            H = get_qubit_hamiltonian(mol, geometry=R, basis=basis, qubit_transf=qubit_transf)
            print("Take a look at H!")
            
            xyz_data = get_molecular_data(mol, geometry=R, xyz_format=True)
            Htq = tq.quantumchemistry.Molecule(geometry=xyz_data, basis_set=basis)

            E_cisd=obtain_PES(mol, [R], basis, 'cisd')
            print('cisd'.upper()," ground state energy is:",E_cisd)
            
            n_spin_orbitals=2*Htq.n_orbitals
            n_electrons=Htq.n_electrons
            print("Numbers of electrons:",n_electrons,
                  "\nUsing ",qubit_transf.upper()," in ",basis.upper(),"basis.",
                  "\nNumber of spin-orbitals (qubits):",n_spin_orbitals,
                  "\nNumber of Hamiltonian terms:",len(H.terms)) 

            H_eff=taper_hamiltonian(H, n_spin_orbitals, n_electrons, qubit_transf)
            print("Number of terms in Taper effective Hamiltonian (H_eff):",len(H_eff.terms))

            
            if mol=='h2':
                # Building the matrix representation of the effective Hamiltonian
                I, X, Z = np.identity(2), np.array([[0, 1], [1, 0]]), np.array([[1, 0], [0, -1]])
                H_matrix = -0.53105134 * I + 0.19679058 * X - 0.53505729 * Z

                # Obtain the eigenvalues
                eigvals, _ = np.linalg.eigh(H_matrix)
                print("The eigenvalues of the effective Hamiltonian:{}".format(eigvals))
            else:
                print("H_matrix for qubit-tapering technique not yet implemeneted for ",mol.upper())

            print(mol.upper(),"Hamiltonian using ",qubit_transf.upper()," in basis:",
                  basis.upper(),"generated for:",time.time()-start," sec\n")
# Out:
# Take a look at H!
# r=1.0000, E =  -1.10115 Eh
# CISD  ground state energy is: [-1.10115033]
# Numbers of electrons: 2
# Using  JW  in  STO-3G basis.
# Number of spin-orbitals (qubits): 4
# Number of Hamiltonian terms: 15
# Number of terms in Taper effective Hamiltonian (H_eff): 3
# The eigenvalues of the effective Hamiltonian:[-1.10115031  0.03904763]
# H2 Hamiltonian using  JW  in basis: STO-3G generated for: 1.5230581760406494  sec
#
# Take a look at H!
# r=1.0000, E =  -1.10115 Eh
# CISD  ground state energy is: [-1.10115033]
# Numbers of electrons: 2
# Using  BK  in  STO-3G basis.
# Number of spin-orbitals (qubits): 4
# Number of Hamiltonian terms: 15
# Number of terms in Taper effective Hamiltonian (H_eff): 3
# The eigenvalues of the effective Hamiltonian:[-1.10115031  0.03904763]
# H2 Hamiltonian using  BK  in basis: STO-3G generated for: 1.4075024127960205  sec
#
# Take a look at H!
# r=1.0000, E =  -1.12678 Eh
# CISD  ground state energy is: [-1.12677835]
# Numbers of electrons: 2
# Using  JW  in  6-31G basis.
# Number of spin-orbitals (qubits): 8
# Number of Hamiltonian terms: 185
# Number of terms in Taper effective Hamiltonian (H_eff): 122
# The eigenvalues of the effective Hamiltonian:[-1.10115031  0.03904763]
# H2 Hamiltonian using  JW  in basis: 6-31G generated for: 1.6652793884277344  sec
#
# Take a look at H!
# r=1.0000, E =  -1.12678 Eh
# CISD  ground state energy is: [-1.12677835]
# Numbers of electrons: 2
# Using  BK  in  6-31G basis.
# Number of spin-orbitals (qubits): 8
# Number of Hamiltonian terms: 185
# Number of terms in Taper effective Hamiltonian (H_eff): 122
# The eigenvalues of the effective Hamiltonian:[-1.10115031  0.03904763]
# H2 Hamiltonian using  BK  in basis: 6-31G generated for: 1.5366744995117188  sec
#
# Take a look at H!
# r=1.0000, E =  -1.91047 Eh
# CISD  ground state energy is: [-1.91046937]
# Numbers of electrons: 4
# Using  JW  in  STO-3G basis.
# Number of spin-orbitals (qubits): 8
# Number of Hamiltonian terms: 93
# Number of terms in Taper effective Hamiltonian (H_eff): 44
# H_matrix for qubit-tapering technique not yet implemeneted for  H4
# H4 Hamiltonian using  JW  in basis: STO-3G generated for: 2.0062193870544434  sec
#
# Take a look at H!
# r=1.0000, E =  -1.91047 Eh
# CISD  ground state energy is: [-1.91046937]
# Numbers of electrons: 4
# Using  BK  in  STO-3G basis.
# Number of spin-orbitals (qubits): 8
# Number of Hamiltonian terms: 105
# Number of terms in Taper effective Hamiltonian (H_eff): 62
# H_matrix for qubit-tapering technique not yet implemeneted for  H4
# H4 Hamiltonian using  BK  in basis: STO-3G generated for: 2.101202964782715  sec
#
# Take a look at H!
# r=1.0000, E =  -2.01994 Eh
# CISD  ground state energy is: [-2.01994061]
# Numbers of electrons: 4
# Using  JW  in  6-31G basis.
# Number of spin-orbitals (qubits): 16
# Number of Hamiltonian terms: 1963
# Number of terms in Taper effective Hamiltonian (H_eff): 1954
# H_matrix for qubit-tapering technique not yet implemeneted for  H4
# H4 Hamiltonian using  JW  in basis: 6-31G generated for: 7.71461820602417  sec
#
# Take a look at H!
# r=1.0000, E =  -2.01994 Eh
# CISD  ground state energy is: [-2.01994061]
# Numbers of electrons: 4
# Using  BK  in  6-31G basis.
# Number of spin-orbitals (qubits): 16
# Number of Hamiltonian terms: 2087
# Number of terms in Taper effective Hamiltonian (H_eff): 2081
# H_matrix for qubit-tapering technique not yet implemeneted for  H4
# H4 Hamiltonian using  BK  in basis: 6-31G generated for: 5.981727600097656  sec
#
# Take a look at H!
# r=1.0000, E =  -7.78445 Eh
# CISD  ground state energy is: [-7.78445187]
# Numbers of electrons: 4
# Using  JW  in  STO-3G basis.
# Number of spin-orbitals (qubits): 12
# Number of Hamiltonian terms: 631
# Number of terms in Taper effective Hamiltonian (H_eff): 558
# H_matrix for qubit-tapering technique not yet implemeneted for  LIH
# LIH Hamiltonian using  JW  in basis: STO-3G generated for: 3.0256948471069336  sec
#
# Take a look at H!
# r=1.0000, E =  -7.78445 Eh
# CISD  ground state energy is: [-7.78445187]
# Numbers of electrons: 4
# Using  BK  in  STO-3G basis.
# Number of spin-orbitals (qubits): 12
# Number of Hamiltonian terms: 631
# Number of terms in Taper effective Hamiltonian (H_eff): 558
# H_matrix for qubit-tapering technique not yet implemeneted for  LIH
# LIH Hamiltonian using  BK  in basis: STO-3G generated for: 2.71700382232666  sec
#
# Take a look at H!
# r=1.0000, E =  -7.89135 Eh
# CISD  ground state energy is: [-7.8913508]
# Numbers of electrons: 4
# Using  JW  in  6-31G basis.
# Number of spin-orbitals (qubits): 22
# Number of Hamiltonian terms: 8750
# Number of terms in Taper effective Hamiltonian (H_eff): 8750
# H_matrix for qubit-tapering technique not yet implemeneted for  LIH
# LIH Hamiltonian using  JW  in basis: 6-31G generated for: 30.179819583892822  sec
#
# Take a look at H!
# r=1.0000, E =  -7.89135 Eh
# CISD  ground state energy is: [-7.8913508]
# Numbers of electrons: 4
# Using  BK  in  6-31G basis.
# Number of spin-orbitals (qubits): 22
# Number of Hamiltonian terms: 8750
# Number of terms in Taper effective Hamiltonian (H_eff): 8750
# H_matrix for qubit-tapering technique not yet implemeneted for  LIH
# LIH Hamiltonian using  BK  in basis: 6-31G generated for: 16.03856921195984  sec
#
# Take a look at H!
# r=1.0000, E = -75.01677 Eh
# CISD  ground state energy is: [-75.01676903]
# Numbers of electrons: 10
# Using  JW  in  STO-3G basis.
# Number of spin-orbitals (qubits): 14
# Number of Hamiltonian terms: 1086
# Number of terms in Taper effective Hamiltonian (H_eff): 1035
# H_matrix for qubit-tapering technique not yet implemeneted for  H2O
# H2O Hamiltonian using  JW  in basis: STO-3G generated for: 4.639539003372192  sec
#
# Take a look at H!
# r=1.0000, E = -75.01677 Eh
# CISD  ground state energy is: [-75.01676903]
# Numbers of electrons: 10
# Using  BK  in  STO-3G basis.
# Number of spin-orbitals (qubits): 14
# Number of Hamiltonian terms: 1086
# Number of terms in Taper effective Hamiltonian (H_eff): 1035
# H_matrix for qubit-tapering technique not yet implemeneted for  H2O
# H2O Hamiltonian using  BK  in basis: STO-3G generated for: 3.3035199642181396  sec
#
# Take a look at H!
# r=1.0000, E = -76.11419 Eh
# CISD  ground state energy is: [-76.11418862]
# Numbers of electrons: 10
# Using  JW  in  6-31G basis.
# Number of spin-orbitals (qubits): 26
# Number of Hamiltonian terms: 12732
# Number of terms in Taper effective Hamiltonian (H_eff): 12723
# H_matrix for qubit-tapering technique not yet implemeneted for  H2O
# H2O Hamiltonian using  JW  in basis: 6-31G generated for: 45.8797972202301  sec
#
# Take a look at H!
# r=1.0000, E = -76.11419 Eh
# CISD  ground state energy is: [-76.11418862]
# Numbers of electrons: 10
# Using  BK  in  6-31G basis.
# Number of spin-orbitals (qubits): 26
# Number of Hamiltonian terms: 12732
# Number of terms in Taper effective Hamiltonian (H_eff): 12723
# H_matrix for qubit-tapering technique not yet implemeneted for  H2O
# H2O Hamiltonian using  BK  in basis: 6-31G generated for: 25.031593322753906  sec
#
# Take a look at H!
# r=1.0000, E = -107.54139 Eh
# CISD  ground state energy is: [-107.54138799]
# Numbers of electrons: 14
# Using  JW  in  STO-3G basis.
# Number of spin-orbitals (qubits): 20
# Number of Hamiltonian terms: 2951
# Number of terms in Taper effective Hamiltonian (H_eff): 2951
# H_matrix for qubit-tapering technique not yet implemeneted for  N2
# N2 Hamiltonian using  JW  in basis: STO-3G generated for: 9.963996171951294  sec
#
# Take a look at H!
# r=1.0000, E = -107.54139 Eh
# CISD  ground state energy is: [-107.54138799]
# Numbers of electrons: 14
# Using  BK  in  STO-3G basis.
# Number of spin-orbitals (qubits): 20
# Number of Hamiltonian terms: 2951
# Number of terms in Taper effective Hamiltonian (H_eff): 2951
# H_matrix for qubit-tapering technique not yet implemeneted for  N2
# N2 Hamiltonian using  BK  in basis: STO-3G generated for: 6.539333820343018  sec
#
# Take a look at H!
# r=1.0000, E = -109.02972 Eh
# CISD  ground state energy is: [-109.02972402]
# Numbers of electrons: 14
# Using  JW  in  6-31G basis.
# Number of spin-orbitals (qubits): 36
# Number of Hamiltonian terms: 34655
# Number of terms in Taper effective Hamiltonian (H_eff): 34655
# H_matrix for qubit-tapering technique not yet implemeneted for  N2
# N2 Hamiltonian using  JW  in basis: 6-31G generated for: 154.83843803405762  sec
#
# Take a look at H!
# r=1.0000, E = -109.02972 Eh
# CISD  ground state energy is: [-109.02972402]
# Numbers of electrons: 14
# Using  BK  in  6-31G basis.
# Number of spin-orbitals (qubits): 36
# Number of Hamiltonian terms: 34655
# Number of terms in Taper effective Hamiltonian (H_eff): 34655
# H_matrix for qubit-tapering technique not yet implemeneted for  N2
# N2 Hamiltonian using  BK  in basis: 6-31G generated for: 75.45214438438416  sec
#
# Take a look at H!
# r=1.0000, E = -55.51402 Eh
# CISD  ground state energy is: [-55.51401798]
# Numbers of electrons: 10
# Using  JW  in  STO-3G basis.
# Number of spin-orbitals (qubits): 16
# Number of Hamiltonian terms: 3609
# Number of terms in Taper effective Hamiltonian (H_eff): 3609
# H_matrix for qubit-tapering technique not yet implemeneted for  NH3
# NH3 Hamiltonian using  JW  in basis: STO-3G generated for: 12.968076944351196  sec
#
# Take a look at H!
# r=1.0000, E = -55.51402 Eh
# CISD  ground state energy is: [-55.51401798]
# Numbers of electrons: 10
# Using  BK  in  STO-3G basis.
# Number of spin-orbitals (qubits): 16
# Number of Hamiltonian terms: 3609
# Number of terms in Taper effective Hamiltonian (H_eff): 3609
# H_matrix for qubit-tapering technique not yet implemeneted for  NH3
# NH3 Hamiltonian using  BK  in basis: STO-3G generated for: 11.51783013343811  sec
#
# Take a look at H!
# r=1.0000, E = -56.28475 Eh
# CISD  ground state energy is: [-56.28475157]
# Numbers of electrons: 10
# Using  JW  in  6-31G basis.
# Number of spin-orbitals (qubits): 30
# Number of Hamiltonian terms: 52806
# Number of terms in Taper effective Hamiltonian (H_eff): 52806
# H_matrix for qubit-tapering technique not yet implemeneted for  NH3
# NH3 Hamiltonian using  JW  in basis: 6-31G generated for: 210.10613489151  sec
#
# Take a look at H!
# r=1.0000, E = -56.28475 Eh
# CISD  ground state energy is: [-56.28475157]
# Numbers of electrons: 10
# Using  BK  in  6-31G basis.
# Number of spin-orbitals (qubits): 30
# Number of Hamiltonian terms: 52806
# Number of terms in Taper effective Hamiltonian (H_eff): 52806
# H_matrix for qubit-tapering technique not yet implemeneted for  NH3
# NH3 Hamiltonian using  BK  in basis: 6-31G generated for: 100.35014772415161  sec
