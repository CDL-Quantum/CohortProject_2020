# %% [markdown]
# # Task #1
#
# A template code for training an RBM on H$_2$ data for $r = 1.2$ is shown here. Modify this!
#
# Imports and loading in data:

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.5.1+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import H2_energy_calculator
from RBM_helper import RBM

# %%
energies = np.zeros([1,53])

for i in range(53):
  if i % 2 == 0:
    R_i = round(0.2 + 0.05*i, 2)
  else:
    R_i = round(0.2 + 0.05*i, 1)
  training_data = torch.from_numpy(np.loadtxt(f"H2_data/R_{(R_i)}_samples.txt"))
  coeff = np.loadtxt("H2_data/H2_coefficients.txt")[20,:]
  true_energy = H2_energy_calculator.energy_from_freq(training_data, coeff)
  print("H2 energy for r =",round(0.2 + 0.05*i, 2),":",true_energy)
  n_vis = 2
  n_hin = 10
  rbm = RBM(n_vis, n_hin)
  epochs = 400 # number of training steps
  num_samples = 1000 # number of samples to generate from the RBM to calculate the H2 energy
  true_energy = H2_energy_calculator.energy_from_freq(training_data, coeff)
  print("True energy: ",true_energy)

  for e in range(1, epochs+1):
      # do one epoch of training
      rbm.train(training_data)   
      # now generate samples and calculate the energy
      if e % 100 == 0:
          print("\nEpoch: ", e)
          print("Sampling the RBM...")
          # For sampling the RBM, we need to do Gibbs sampling.
          # Initialize the Gibbs sampling chain with init_state as defined below.
          init_state = torch.zeros(num_samples, n_vis)
          RBM_samples = rbm.draw_samples(15, init_state)
          print("Done sampling. Calculating energy...")       
          energies[0, i] = H2_energy_calculator.energy(RBM_samples, coeff, rbm.wavefunction) 
          print("Energy from RBM samples: ", energies[0, i].item())
# Out:
# H2 energy for r = 0.2 : -1.0272612255781348
# True energy:  -1.0272612255781348
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.006476823066262
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.010257474109587
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0075996870167025
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0116358943933892
# H2 energy for r = 0.25 : -1.0272612255781348
# True energy:  -1.0272612255781348
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0091785037620777
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0129866344424034
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0115076567596148
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0116686744784242
# H2 energy for r = 0.3 : -1.0289787152870253
# True energy:  -1.0289787152870253
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0082048511253778
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0120517930306956
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.009144783277552
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0091660217228744
# H2 energy for r = 0.35 : -1.0339439695134862
# True energy:  -1.0339439695134862
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0044087171115095
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0028601953748408
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0084057420875663
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.012443530203645
# H2 energy for r = 0.4 : -1.0339439695134862
# True energy:  -1.0339439695134862
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0011732618189761
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0009403774102057
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.011044665596156
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.001595690250425
# H2 energy for r = 0.45 : -1.0380608769339534
# True energy:  -1.0380608769339534
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0062141932305557
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.007792949840441
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0055503243048636
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0043869070718876
# H2 energy for r = 0.5 : -1.0380608769339534
# True energy:  -1.0380608769339534
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9962557170173428
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9962986844448659
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.007548457612872
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0062266657073302
# H2 energy for r = 0.55 : -1.0430990090273842
# True energy:  -1.0430990090273842
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.991157265386014
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9929312216384223
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0132740170345331
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.000445500611977
# H2 energy for r = 0.6 : -1.0430990090273842
# True energy:  -1.0430990090273842
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0023046361382757
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.998322926662608
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0018438980485531
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0105467099206074
# H2 energy for r = 0.65 : -1.046658951711928
# True energy:  -1.046658951711928
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.009273466323864
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.02250372244261
#
# Epoch:  300
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9854080396356406
#
# Epoch:  400
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0141207158593026
# H2 energy for r = 0.7 : -1.046658951711928
# True energy:  -1.046658951711928
#
# Epoch:  100
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0034356767033152
#
# Epoch:  200
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.